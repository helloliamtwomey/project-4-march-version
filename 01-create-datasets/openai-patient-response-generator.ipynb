# %% [markdown]
# open ai chatgpt patient response generator
#
# 1.	Please describe the reason for your visit today and the specific symptoms you are experiencing?
# 2.	Please describe the experience you've had with your symptoms?
# 3.	How long have you been experiencing these symptoms?
# 4.	How severe are the symptoms? In terms of mild, moderate, or severe.
# 5.	Are there any other symptoms you are experiencing along with the main symptoms?
# 6.	Do you have any past medical history or conditions that may be relevant to your symptoms?
# 7.	What are your expectations for your appointment today?

# %%
"""
I\'m conducting a project that uses machine learning to classify responses to a pre-appointment questionnaire based on the symptoms or health issues reported by patients

1.	Please provide a brief summary of the reason for your visit today and the symptoms you are experiencing.
2.	How long have you been experiencing these symptoms?
3.	How would you describe the types of symptoms you are experiencing?
4.	How severe are the symptoms? In terms of mild, moderate, or severe.
5.	What do you believe is causing the symptoms?
6.	Are there any other symptoms you are experiencing along with the main symptoms?
7.	Do you have any past medical history or conditions that may be relevant to your symptoms?
8.	What are your expectations for your appointment today?
9.	Do you have any concerns or fears about your health that you would like to discuss with your healthcare provider?
10.	Can you describe your overall feelings and experiences with your health and healthcare?

Generate dataframe of phrases that patients experiencing respiratory health issues might say in response to the questions above, concidering way/'s patients experiencing respiratory health issue\'s might describe their symptoms

base dataframe of phrases on the following example text

df = pd.DataFrame(columns=["reason_for_visit", "symptoms", "duration", "symptom_type", "symptom_severity", "symptom_cause", "additional_symptoms", "medical_history", "appointment_expectations", "health_concerns", "health_experiences"])

# add a row of data for each patient's response
df.loc[1] = ['Chest pain', 'Cough, shortness of breath, chest pain', '2 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis', 'Worried about my heart', 'Scared and anxious']
df.loc[2] = ['Difficulty breathing', 'Shortness of breath, coughing, wheezing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my lung health', 'Frustrated and overwhelmed']
"""

# %%
"""
can you produce more creative and varied examples that would follow?
df.loc[11] =
df.loc[12] =
df.loc[13] =
df.loc[14] =
"""

# %%
"""
import pandas as pd

df_respiratory = pd.DataFrame(columns=["reason_for_visit", "symptoms", "duration", "symptom_type", "symptom_severity", "symptom_cause", "additional_symptoms", "medical_history", "appointment_expectations", "health_concerns", "health_experiences"])

df_respiratory.loc[0] = ['Chest pain', 'Cough, shortness of breath, chest pain', '2 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis', 'Worried about my heart', 'Scared and anxious']
df_respiratory.loc[1] = ['Difficulty breathing', 'Shortness of breath, coughing, wheezing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my lung health', 'Frustrated and overwhelmed']
df_respiratory.loc[3] = ['Chronic coughing', 'Coughing, chest pain, difficulty breathing', '6 months', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my lung health', 'Feeling very tired and weak']
df_respiratory.loc[4] = ['Chronic bronchitis', 'Coughing, chest pain, difficulty breathing', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'Chronic bronchitis', 'To receive a treatment plan and medication', 'Concerned about my lung health', 'Feeling very sick and short of breath']
df_respiratory.loc[5] = ['Bronchitis symptoms', 'Coughing, chest pain, difficulty breathing', '2 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and tired']
df_respiratory.loc[6] = ['Bronchitis flare-up', 'Coughing, chest pain, difficulty breathing, fatigue', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a treatment plan and medication', 'Worried about my lung health', 'Feeling very sick and short of breath']
df_respiratory.loc[7] = ['Chronic cough', 'Coughing, chest pain, difficulty breathing, fatigue', '6 months', 'Respiratory', 'Severe', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and short of breath']
df_respiratory.loc[8] = ['Bronchitis symptoms', 'Coughing, chest pain, difficulty breathing, fatigue', '2 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and tired']
df_respiratory.loc[9] = ['Cough and chest pain', 'Coughing, chest pain, difficulty breathing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and short of breath']
df_respiratory.loc[11] = ['Chronic bronchitis symptoms', 'Coughing, chest pain, difficulty breathing, fatigue', '6 months', 'Respiratory', 'Moderate', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a treatment plan and medication', 'Worried about my lung health', 'Feeling very sick and short of breath']
df_respiratory.loc[12] = ['Chronic cough', 'Coughing, chest pain, difficulty breathing, fatigue', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and short of breath']
df_respiratory.loc[13] = ['Bronchitis symptoms', 'Coughing, chest pain, difficulty breathing, fatigue', '2 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and tired']
df_respiratory.loc[14] = ['Cough and chest pain', 'Coughing, chest pain, difficulty breathing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and short of breath']
df_respiratory.loc[15] = ['Difficulty breathing', 'Shortness of breath, coughing, wheezing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my lung health', 'Frustrated and overwhelmed']
df_respiratory.loc[16] = ['Chest pain and difficulty breathing', 'Chest pain, difficulty breathing, coughing', '2 weeks', 'Respiratory', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and scared']
df_respiratory.loc[17] = ['Shortness of breath and chest pain', 'Shortness of breath, chest pain, coughing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and scared']
df_respiratory.loc[18] = ['Difficulty breathing and wheezing', 'Difficulty breathing, wheezing, coughing', '2 weeks', 'Respiratory', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my lung health', 'Feeling very sick and overwhelmed']
df_respiratory.loc[19] = ['Chest pain and coughing', 'Chest pain, coughing, difficulty breathing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and scared']
df_respiratory.loc[20] = ['Wheezing and difficulty breathing', 'Wheezing, difficulty breathing, coughing', '2 weeks', 'Respiratory', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my lung health', 'Feeling very sick and overwhelmed']
df_respiratory.loc[21] = ['Chronic bronchitis symptoms', 'Coughing, chest pain, difficulty breathing, fatigue', '6 months', 'Respiratory', 'Moderate', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a treatment plan and medication', 'Worried about my lung health', 'Feeling very sick and short of breath']
df_respiratory.loc[22] = ['Chronic cough', 'Coughing, chest pain, difficulty breathing, fatigue', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and short of breath']
df_respiratory.loc[23] = ['Respiratory distress', 'Can\'t catch my breath, chest feels heavy, coughing, wheezing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[24] = ['Cough and chest pain', 'Coughing, chest pain, need some air, feeling winded, difficulty breathing', '2 weeks', 'Respiratory', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and can\'t get enough air']
df_respiratory.loc[25] = ['Respiratory infection symptoms', 'Can\'t get my breath, chest feels tight, coughing, wheezing', '3 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[26] = ['Chronic cough and chest pain', 'Coughing, chest pain, can\'t get enough air, feeling winded, difficulty breathing', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and can\'t get enough air']
df_respiratory.loc[27] = ['Respiratory symptoms', 'Can\'t catch my breath, chest feels heavy, coughing, wheezing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[28] = ['Chest pain and chronic cough', 'Coughing, chest pain, can\'t get enough air, feeling winded, difficulty breathing', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and can\'t get enough air']
df_respiratory.loc[29] = ['Respiratory issues', 'Can\'t get my breath, chest feels tight, coughing, wheezing', '3 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[30] = ['Chest pain and chronic cough', 'Coughing, chest pain, can\'t get enough air, feeling winded, difficulty breathing', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and can\'t get enough air']
df_respiratory.loc[31] = ['Respiratory problems', 'Can\'t catch my breath, chest feels heavy, coughing, wheezing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[33] = ['Respiratory issues', 'Can\'t get my breath, chest feels tight, coughing, wheezing', '3 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[33] = ['Respiratory issues', 'Can\'t get my breath, chest feels tight, coughing, wheezing', '3 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[34] = ['Seeking treatment for chronic cough and chest pain', 'Coughing, chest pain, can\'t get enough air, feeling winded, difficulty breathing', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and can\'t get enough air']
df_respiratory.loc[35] = ['Seeking treatment for chronic cough and chest pain', 'Coughing, chest pain, can\'t get enough air, feeling winded, difficulty breathing', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and can\'t get enough air']
df_respiratory.loc[36] = ['Checking in on chronic bronchitis symptoms', 'Can\'t get my breath, chest feels tight, coughing, wheezing', '3 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive an updated treatment plan and medication', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[37] = ['Following up on chronic bronchitis symptoms', 'Can\'t catch my breath, chest feels heavy, coughing, wheezing, difficulty breathing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive an updated treatment plan and medication', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[38] = ['Seeking treatment for chronic cough and chest pain', 'Coughing, chest pain, can\'t get enough air, feeling winded, difficulty breathing, shortness of breath', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and can\'t get enough air']
df_respiratory.loc[39] = ['Following up on chronic bronchitis symptoms', 'Can\'t get my breath, chest feels tight, coughing, wheezing, difficulty breathing', '3 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive an updated treatment plan and medication', 'Worried about my lung health', 'Feeling very sick and struggling to breathe']
df_respiratory.loc[40] = ['Seeking treatment for chronic cough and chest pain', 'Coughing, chest pain, can\'t get enough air, feeling winded, difficulty breathing, shortness of breath', '1 year', 'Respiratory', 'Severe', 'Unknown', 'None', 'Bronchitis, asthma', 'To receive a diagnosis and treatment plan', 'Worried about my heart and lung health', 'Feeling very sick and can\'t get enough air']
df_respiratory.loc[41] = ['Cough and chest pain', 'Cough, chest pain, fever', '1 week', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my lung health', 'Frustrated and overwhelmed']
df_respiratory.loc[42] = ['Chest pain', 'Cough, shortness of breath, chest pain', '2 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis', 'Worried about my heart', 'Scared and anxious']
df_respiratory.loc[43] = ['Difficulty breathing', 'Shortness of breath, coughing, wheezing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my lung health', 'Frustrated and overwhelmed']
df_respiratory.loc[44] = ['Coughing and wheezing', 'Cough, wheezing, difficulty breathing', '3 weeks', 'Respiratory', 'Mild', 'Unknown', 'None', 'Asthma', 'To receive treatment for my symptoms', 'Worried about my asthma', 'Annoyed and frustrated']
df_respiratory.loc[45] = ['Breathing problems', 'Cough, wheezing, difficulty breathing', '3 days', 'Respiratory', 'Severe', 'Unknown', 'None', 'Asthma', 'To receive treatment', 'Worried about my asthma', 'Frustrated and concerned']
df_respiratory.loc[46] = ['Shortness of breath', 'Shortness of breath, coughing, chest tightness', '1 week', 'Respiratory', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my lung health', 'Nervous and unsure']
df_respiratory.loc[47] = ['Chronic cough', 'Cough, chest pain, phlegm production', '6 months', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Tired of dealing with this issue']
df_respiratory.loc[48] = ['Sinus infection', 'Cough, congestion, sinus pressure', '2 weeks', 'Respiratory', 'Mild', 'Sinus infection', 'None', 'None', 'To receive treatment for sinus infection', 'Concerned about the duration of the infection', 'Frustrated and uncomfortable']
df_respiratory.loc[49] = ['Flu symptoms', 'Cough, congestion, fever, body aches', '1 week', 'Respiratory', 'Moderate', 'Influenza virus', 'None', 'None', 'To receive treatment for the flu', 'Concerned about complications', 'Tired and miserable']
df_respiratory.loc[50] = ['Pneumonia symptoms', 'Cough, fever, difficulty breathing, chest pain', '3 days', 'Respiratory', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Scared and in pain']
df_respiratory.loc[51] = ['Bronchitis symptoms', 'Cough, phlegm production, chest pain', '2 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Frustrated and uncomfortable']
df_respiratory.loc[52] = ['Sore throat', 'Sore throat, coughing, congestion', '4 days', 'Respiratory', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the duration of the symptoms', 'Annoyed and uncomfortable']
df_respiratory.loc[53] = ['Choking sensation', 'Cough, difficulty swallowing, chest pain', '1 week', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my throat health', 'Scared and unsure']
df_respiratory.loc[54] = ['Allergies', 'Cough, congestion, watery eyes', '2 weeks', 'Respiratory', 'Mild', 'Allergic reaction', 'None', 'None', 'To receive treatment for allergies', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[55] = ['Allergies', 'Cough, congestion, watery eyes', '2 weeks', 'Respiratory', 'Mild', 'Allergic reaction', 'None', 'None', 'To receive treatment for allergies', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[56] = ['Coughing spells', 'Cough, chest pain, difficulty breathing', '1 month', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Scared and anxious']
df_respiratory.loc[57] = ['Smoke inhalation', 'Cough, chest pain, difficulty breathing', '2 days', 'Respiratory', 'Severe', 'Smoke inhalation', 'None', 'None', 'To receive treatment for smoke inhalation', 'Worried about my lung health', 'Scared and in pain']
df_respiratory.loc[58] = ['Sinus pressure', 'Cough, congestion, headache', '1 week', 'Respiratory', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[59] = ['Bronchitis symptoms', 'Cough, phlegm production, chest pain', '2 weeks', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Frustrated and uncomfortable']
df_respiratory.loc[60] = ['Sore throat', 'Sore throat, coughing, congestion', '4 days', 'Respiratory', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the duration of the symptoms', 'Annoyed and uncomfortable']
df_respiratory.loc[61] = ['Pet dander allergy', 'Cough, sneezing, watery eyes', '1 week', 'Respiratory', 'Mild', 'Allergic reaction', 'None', 'None', 'To receive treatment for pet dander allergies', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[62] = ['Dog allergy', 'Cough, sneezing, watery eyes', '2 weeks', 'Respiratory', 'Mild', 'Allergic reaction', 'None', 'None', 'To receive treatment for dog allergies', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[63] = ['Cat allergy', 'Cough, sneezing, watery eyes', '2 weeks', 'Respiratory', 'Mild', 'Allergic reaction', 'None', 'None', 'To receive treatment for cat allergies', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[64] = ['Workplace exposure', 'Cough, chest pain, difficulty breathing', '1 week', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Scared and anxious']
df_respiratory.loc[65] = ['Exposure to chemicals', 'Cough, sneezing, watery eyes', '2 weeks', 'Respiratory', 'Mild', 'Allergic reaction', 'None', 'None', 'To receive treatment for chemical exposure', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[66] = ['Lung infection', 'Cough, chest pain, difficulty breathing', '1 week', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Scared and anxious']
df_respiratory.loc[67] = ['Sinus infection', 'Cough, congestion, sinus pressure', '2 weeks', 'Respiratory', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[68] = ['Exposure to allergens', 'Cough, sneezing, watery eyes', '2 weeks', 'Respiratory', 'Mild', 'Allergic reaction', 'None', 'None', 'To receive treatment for allergies', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[69] = ['Cold weather', 'Cough, chest pain, difficulty breathing', '1 week', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Scared and anxious']
df_respiratory.loc[70] = ['Allergies to pollen', 'Cough, sneezing, watery eyes', '2 weeks', 'Respiratory', 'Mild', 'Allergic reaction', 'None', 'None', 'To receive treatment for pollen allergies', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[71] = ['Storm exposure', 'Cough, chest pain, difficulty breathing', '1 week', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Scared and anxious']
df_respiratory.loc[72] = ['Exposure to mold', 'Cough, sneezing, watery eyes', '2 weeks', 'Respiratory', 'Mild', 'Allergic reaction', 'None', 'None', 'To receive treatment for mold exposure', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']
df_respiratory.loc[73] = ['Training for a race', 'Cough, chest pain, difficulty breathing', '1 week', 'Respiratory', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my lung health', 'Scared and anxious']
df_respiratory.loc[74] = ['Exercise-induced asthma', 'Cough, wheezing, shortness of breath', '2 weeks', 'Respiratory', 'Mild', 'Exercise', 'None', 'None', 'To receive treatment for exercise-induced asthma', 'Concerned about the duration of the symptoms', 'Frustrated and uncomfortable']

df.head()

# export to csv
# df.to_csv('respiratory-responses.csv', index=False)
"""

# %%
"""
# dataframe for digestive health issues
df_digestive = pd.DataFrame(columns=["reason_for_visit", "symptoms", "duration", "symptom_type", "symptom_severity", "symptom_cause", "additional_symptoms", "medical_history", "appointment_expectations", "health_concerns", "health_experiences"])

# add rows of data for each patient's response
df_digestive.loc[1] = ['Nausea, vomiting, diarrhea', 'Abdominal pain, bloating, loss of appetite', '1 week', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[2] = ['Heartburn, acid reflux, bloating', 'Nausea, vomiting, constipation', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[3] = ['Abdominal pain, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[4] = ['Nausea, vomiting, abdominal pain', 'Diarrhea, constipation, bloating', '3 days', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[5] = ['Diarrhea, constipation, bloating', 'Nausea, vomiting, abdominal pain', '2 weeks', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[6] = ['Heartburn, acid reflux, bloating', 'Nausea, vomiting, diarrhea', '1 month', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[7] = ['Abdominal pain, bloating, gas', 'Nausea, vomiting, diarrhea', '2 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[8] = ['Heartburn, acid reflux, bloating', 'Nausea, vomiting, constipation', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[9] = ['Abdominal pain, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[10] = ['Nausea, vomiting, abdominal pain', 'Diarrhea, constipation, bloating', '3 days', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[11] = ['Feeling sick to my stomach', 'Throwing up, can\'t go to the bathroom', '2 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[12] = ['My stomach is killing me', 'I feel like I\'m going to hurl, I\'m puking my guts out', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[13] = ['I can\'t stop shitting, my stomach is all twisted up', 'I\'ve got a gut ache, I can\'t hold down any food', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[14] = ['I\'ve got the trots, I\'ve got a bellyache', 'Nausea, vomiting, abdominal pain', '3 days', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[15] = ['Feeling nauseous and dizzy', 'Vomiting, diarrhea, abdominal pain', '2 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[16] = ['Heartburn, acid reflux, bloating', 'Nausea, vomiting, constipation', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[17] = ['Abdominal pain, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[18] = ['Feeling sick to my stomach', 'Throwing up, can\'t go to the bathroom', '3 days', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[19] = ['Feeling sick to my stomach', 'Throwing up, diarrhea, abdominal pain', '2 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[20] = ['Heartburn, acid reflux, bloating', 'Nausea, vomiting, constipation', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[21] = ['Abdominal pain, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[22] = ['Feeling sick to my stomach', 'Throwing up, can\'t go to the bathroom', '3 days', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[23] = ['Feeling nauseous and dizzy', 'Vomiting, diarrhea, abdominal pain', '2 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[24] = ['Heartburn, acid reflux, bloating', 'Nausea, vomiting, constipation', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[25] = ['Abdominal pain, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[26] = ['Feeling sick to my stomach', 'Throwing up, can\'t go to the bathroom', '3 days', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[27] = ['Feeling nauseous and dizzy', 'Vomiting, diarrhea, abdominal pain', '2 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[28] = ['Heartburn, acid reflux, bloating', 'Nausea, vomiting, constipation', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[29] = ['Abdominal pain, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[30] = ['Feeling sick to my stomach', 'Throwing up, can\'t go to the bathroom', '3 days', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[31] = ['Feeling nauseous and dizzy', 'Vomiting, diarrhea, abdominal pain', '2 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[32] = ['Heartburn, acid reflux, bloating', 'Nausea, vomiting, constipation', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[33] = ['Abdominal pain, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[34] = ['Feeling sick to my stomach', 'Throwing up, can\'t go to the bathroom', '3 days', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[35] = ['Gut ache, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[36] = ['Feeling sick to my stomach', 'Throwing up, can\'t go to the bathroom', '3 days', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[37] = ['Abdominal pain, bloating, gas', 'Nausea, vomiting, constipation', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[38] = ['Gut ache, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[39] = ['Feeling like I can\'t keep anything down', 'Vomiting, diarrhea, abdominal cramps', '1 week', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[40] = ['Constant heartburn and acid reflux', 'Nausea, vomiting, bloating', '1 month', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[41] = ['Abdominal pain, bloating, gas', 'Diarrhea, constipation, loss of appetite', '1 week', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[42] = ['Feeling like I\'m constantly bloated', 'Diarrhea, constipation, loss of appetite', '2 weeks', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[43] = ['I can\'t seem to get rid of this stomachache', 'Bloating, gas, abdominal pain', '3 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[44] = ['Feeling like I have to go to the bathroom all the time', 'Diarrhea, constipation, bloating', '1 month', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[45] = ['My stomach is constantly in knots', 'Nausea, vomiting, bloating', '1 week', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[46] = ['Feeling like I can\'t keep anything down', 'Vomiting, diarrhea, abdominal cramps', '1 week', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[47] = ['Feeling like I\'m constantly bloated', 'Diarrhea, constipation, loss of appetite', '2 weeks', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[48] = ['I can\'t seem to get rid of this stomachache', 'Bloating, gas, abdominal pain', '3 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[49] = ['Feeling like I have to go to the bathroom all the time', 'Diarrhea, constipation, bloating', '1 month', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[50] = ['My stomach is constantly in knots', 'Nausea, vomiting, bloating', '1 week', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[51] = ['I feel like I\'m constantly going to the bathroom', 'Diarrhea, constipation, bloating', '2 months', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[52] = ['I can\'t seem to keep anything down', 'Nausea, vomiting, bloating', '1 week', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[53] = ['I have a constant feeling of bloating and discomfort', 'Diarrhea, constipation, abdominal pain', '3 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[54] = ['I\'m constantly feeling sick to my stomach', 'Nausea, vomiting, bloating', '1 month', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[55] = ['I\'m constantly experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '2 months', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[56] = ['I can\'t seem to keep anything down', 'Nausea, vomiting, abdominal pain', '1 week', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[57] = ['I have a constant feeling of bloating and discomfort', 'Diarrhea, constipation, abdominal pain', '3 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[58] = ['I\'m constantly feeling sick to my stomach', 'Nausea, vomiting, bloating', '1 month', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[59] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '1 week', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[60] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '1 month', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[61] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '2 months', 'Digestive issues', 'Severe', 'Unknown', 'None', 'Irritable bowel syndrome', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[62] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '1 week', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'Crohn\'s disease', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[63] = ['I have been experiencing frequent stomach issues', 'Nausea, vomiting, diarrhea', '2 months', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[64] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '1 month', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[65] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '3 months', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[65] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '2 weeks', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[66] = ['I have been experiencing frequent stomach issues', 'Nausea, vomiting, diarrhea', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[67] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '3 months', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[68] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '2 months', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[69] = ['I have been experiencing stomach pain and discomfort', 'Abdominal cramps, bloating, gas', '1 week', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[70] = ['I have been feeling sick to my stomach', 'Nausea, vomiting, diarrhea', '1 week', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[71] = ['I have been throwing up', 'Nausea, vomiting, diarrhea', '2 months', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[72] = ['I have been experiencing the runs', 'Nausea, vomiting, diarrhea', '1 month', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[73] = ['I can\'t go to the bathroom', 'Constipation, bloating, gas', '2 weeks', 'Digestive issues', 'Mild', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[74] = ['I have been experiencing a lot of stomach pain', 'Abdominal pain, bloating, gas', '1 week', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[75] = ['I feel like I\'m going to hurl', 'Nausea, vomiting, abdominal pain', '1 week', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_digestive.loc[76] = ['I\'m puking my guts out', 'Nausea, vomiting, abdominal pain', '1 month', 'Digestive issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_digestive.loc[77] = ['I can\'t stop shitting', 'Diarrhea, abdominal pain, bloating', '2 weeks', 'Digestive issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
"""

# %%
"""
df_mental = pd.DataFrame(columns=["reason_for_visit", "symptoms", "duration", "symptom_type", "symptom_severity", "symptom_cause", "additional_symptoms", "medical_history", "appointment_expectations", "health_concerns", "health_experiences"])

df_mental.loc[1] = ['I\'m feeling really blue', 'Depression, anxiety, stress, sleep problems', '6 months', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_mental.loc[2] = ['I\'m anxious all the time', 'Anxiety, stress, irritability', '2 weeks', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_mental.loc[3] = ['I\'m stressed out', 'Stress, mood swings, difficulty concentrating', '1 month', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_mental.loc[4] = ['I\'m all over the place emotionally', 'Mood swings, irritability, loss of interest in activities', '1 week', 'Mental health issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_mental.loc[5] = ['I\'m feeling down', 'Depression, stress, sleep problems', '3 months', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_mental.loc[6] = ['I can\'t sleep', 'Anxiety, stress, sleep problems', '1 month', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_mental.loc[7] = ['I\'m easily annoyed', 'Stress, irritability, mood swings', '2 weeks', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the long-term effects of my symptoms', 'Frustrated and overwhelmed']
df_mental.loc[8] = ['I can\'t focus', 'Stress, anxiety, difficulty concentrating', '1 week', 'Mental health issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_mental.loc[9] = ["Feeling depressed", "Lack of motivation, difficulty sleeping, irritability", "1 month", "Mental health", "Moderate", "Unknown", "None", "None", "To receive a diagnosis and treatment plan", "Concerned about my ability to function at work", "Feeling hopeless and helpless"]
df_mental.loc[10] = ["Anxiety and stress", "Constant worrying, difficulty concentrating, social withdrawal", "3 months", "Mental health", "Severe", "Unknown", "None", "None", "To receive support and guidance", "Worried about the impact on my relationships", "Feeling overwhelmed and stressed out"]
df_mental.loc[11] = ["Mood swings", "Irritability, loss of interest in activities, sleep problems", "1 year", "Mental health", "Moderate", "Unknown", "None", "None", "To receive treatment and support", "Concerned about my overall well-being", "Feeling frustrated and uncertain"]
df_mental.loc[12] = ["Feeling overwhelmed", "Anxiety, stress, lack of motivation", "6 months", "Mental health", "Severe", "Unknown", "None", "None", "To receive a diagnosis and treatment plan", "Worried about the long-term effects on my health", "Feeling anxious and stressed"]
df_mental.loc[13] = ["Depression", "Lack of interest in activities, social withdrawal, sleep problems", "2 years", "Mental health", "Moderate", "Unknown", "None", "None", "To receive support and guidance", "Concerned about the impact on my daily life", "Feeling hopeless and lost"]
df_mental.loc[14] = ['Mood swings and social withdrawal', 'Sleep problems, irritability, difficulty concentrating', '2 months', 'Mental health issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the impact on my work and relationships', 'Scared and overwhelmed']
df_mental.loc[15] = ['Feeling down and anxious', 'Lack of motivation, loss of interest in activities', '3 months', 'Depression and anxiety', 'Moderate', 'Unknown', 'None', 'None', 'To discuss medication options and therapy options', 'Worried about the long-term effects on my mental health', 'Sad and hopeless']
df_mental.loc[16] = ['Feeling stressed out', 'Mood swings, sleep problems, difficulty concentrating', '1 week', 'Stress', 'Mild', 'Work and family responsibilities', 'None', 'None', 'To discuss coping strategies and stress management techniques', 'Concerned about the potential negative effects on my physical health', 'Frustrated and overwhelmed']
df_mental.loc[17] = ['Feeling overwhelmed and irritable', 'Anxiety, mood swings, sleep problems', '6 months', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about the stigma surrounding mental health', 'Anxious and scared']
df_mental.loc[18] = ['Feeling down and anxious', 'Lack of motivation, social withdrawal', '1 year', 'Depression and anxiety', 'Severe', 'Unknown', 'None', 'None', 'To discuss medication options and therapy options', 'Concerned about the impact on my relationships and daily life', 'Sad and hopeless']
df_mental.loc[19] = ['Feeling overwhelmed and stressed', 'Irritability, mood swings, sleep problems', '1 week', 'Mental health issues', 'Moderate', 'Work stress', 'None', 'None', 'To receive support and advice', 'Worried about my mental health', 'Scared and anxious']
df_mental.loc[20] = ['Depression and anxiety', 'Lack of motivation, social withdrawal, difficulty concentrating', '2 months', 'Mental health issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my ability to function', 'Frustrated and overwhelmed']
df_mental.loc[21] = ['Feeling down and hopeless', 'Loss of interest in activities, sleep problems, irritability', '3 months', 'Mental health issues', 'Severe', 'Unknown', 'None', 'None', 'To receive medication and therapy', 'Worried about the long-term effects on my life', 'Sad and defeated']
df_mental.loc[22] = ['Struggling with anxiety and stress', 'Sleep problems, mood swings, difficulty concentrating', '1 year', 'Mental health issues', 'Moderate', 'Life stressors', 'None', 'None', 'To receive support and coping strategies', 'Concerned about my mental health', 'Frustrated and overwhelmed']
df_mental.loc[23] = ['Feeling down and hopeless', 'Loss of motivation, social withdrawal, irritability', '6 months', 'Mental health issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my future', 'Sad and defeated']
df_mental.loc[24] = ['Stress, anxiety, irritability', 'Difficulty sleeping, lack of motivation, mood swings', '2 months', 'Mental health issues', 'Moderate', 'Work-related stress', 'None', 'None', 'To discuss treatment options and receive support', 'Concerned about the impact on my relationships and work performance', 'Exhausted and overwhelmed']
df_mental.loc[25] = ['I feel depressed and anxious all the time', 'Sleep problems, lack of interest in activities, difficulty concentrating', '1 year', 'Depression and anxiety', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Scared of the long-term effects on my mental health', 'Hopeless and alone']
df_mental.loc[26] = ['I\'m not feeling like myself', 'Mood swings, irritability, social withdrawal', '6 months', 'Mental health issues', 'Mild', 'Unknown', 'None', 'None', 'To receive support and guidance', 'Concerned about the potential causes of my symptoms', 'Confused and scared']
df_mental.loc[27] = ['I\'m struggling with stress and anxiety', 'Sleep problems, lack of motivation, difficulty concentrating', '3 months', 'Mental health issues', 'Moderate', 'Work-related stress', 'None', 'None', 'To receive support and guidance', 'Concerned about the impact on my work and relationships', 'Exhausted and overwhelmed']
df_mental.loc[28] = ['I\'m not feeling like myself', 'Mood swings, irritability, social withdrawal', '6 months', 'Mental health issues', 'Mild', 'Unknown', 'None', 'None', 'To receive support and guidance', 'Concerned about the potential causes of my symptoms', 'Confused and scared']
df_mental.loc[29] = ['Depressed and anxious', 'Lack of energy, Sleep problems, Irritability, Difficulty concentrating', '2 months', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my ability to function at work and in my personal life', 'Hopeless and helpless']
df_mental.loc[30] = ['Feeling overwhelmed', 'Excessive worrying, Mood swings, Social withdrawal, Loss of interest in activities', '1 year', 'Anxiety disorder', 'Severe', 'Unknown', 'None', 'None', 'To receive medication and therapy', 'Afraid of losing control and having a panic attack', 'Embarrassed and ashamed']
df_mental.loc[31] = ['Feeling burnt out', 'Insomnia, Lack of motivation, Irritability, Headaches', '3 months', 'Stress', 'Mild', 'Work and family responsibilities', 'None', 'None', 'To learn coping skills and relaxation techniques', 'Worried about the long-term effects on my health', 'Exhausted and drained']
df_mental.loc[32] = ['Feeling down', 'Sleeping too much or too little, Appetite changes, Lack of interest in hobbies, Feeling hopeless', '6 months', 'Depression', 'Moderate', 'Unknown', 'None', 'None', 'To receive a combination of medication and therapy', 'Concerned about the impact on my relationships', 'Lonely and isolated']
df_mental.loc[33] = ['Feeling out of control', 'Racing thoughts, Impulsive behavior, Agitation, Substance abuse', '1 year', 'Bipolar disorder', 'Severe', 'Unknown', 'None', 'None', 'To receive regular medication and therapy', 'Afraid of hurting myself or others', 'Terrified and desperate']
df_mental.loc[34] = ['Feeling depressed and anxious', 'Difficulty sleeping, lack of motivation, irritability', '2 months', 'Mental health', 'Moderate', 'Stressful work environment', 'None', 'None', 'To discuss treatment options with my healthcare provider', 'Worried about my mental health getting worse', 'Feeling hopeless and helpless']
df_mental.loc[35] = ['Mood swings and sleep problems', 'Anxiety, difficulty concentrating, loss of interest in activities', '6 months', 'Mental health', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the impact on my relationships', 'Feeling overwhelmed and scared']
df_mental.loc[36] = ['Feeling stressed and overwhelmed', 'Mood swings, irritability, social withdrawal', '1 week', 'Mental health', 'Mild', 'Personal problems', 'None', 'None', 'To talk to my healthcare provider and get support', 'Worried about my ability to cope with stress', 'Feeling lost and alone']
df_mental.loc[37] = ['Feeling down and hopeless', 'Lack of motivation, loss of appetite, sleep problems', '3 months', 'Mental health', 'Moderate', 'Relationship issues', 'None', 'None', 'To discuss medication options with my healthcare provider', 'Concerned about my future and my ability to improve', 'Feeling helpless and desperate']
df_mental.loc[38] = ['Feeling anxious and on edge', 'Irritability, difficulty concentrating, social withdrawal', '1 month', 'Mental health', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Worried about my mental health and how it will affect my life', 'Feeling scared and uncertain']
df_mental.loc[39] = ['Depression and anxiety', 'Lack of motivation, social withdrawal, difficulty concentrating', '2 months', 'Mental health issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about my ability to function', 'Frustrated and overwhelmed']
df_mental.loc[40] = ['Feeling down', 'Tired all the time, lack of motivation, mood swings', '2 months', 'Depression', 'Moderate', 'Stressful life events', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the impact on my relationships and work', 'Hopeless and helpless']
df_mental.loc[41] = ['Stress at work', 'Headaches, muscle tension, sleep problems', '1 month', 'Stress', 'Mild', 'Workplace stress', 'None', 'None', 'To learn coping strategies and relaxation techniques', 'Concerned about the long-term effects on my health', 'Frustrated and overwhelmed']
df_mental.loc[42] = ['Mood swings', 'Irritability, difficulty concentrating, social withdrawal', '3 months', 'Bipolar disorder', 'Moderate', 'Genetic predisposition', 'None', 'None', 'To discuss medication and therapy options', 'Worried about the impact on my relationships and daily life', 'Confused and ashamed']
df_mental.loc[43] = ['Feeling overwhelmed', 'Insomnia, loss of appetite, lack of interest in activities', '1 month', 'Depression', 'Mild', 'Life transitions', 'None', 'None', 'To receive support and guidance', 'Concerned about the impact on my mental health', 'Sad and lonely']
df_mental.loc[44] = ['Anxiety attacks', 'Racing thoughts, difficulty sleeping, irritability', '6 months', 'Anxiety disorder', 'Severe', 'Unknown', 'None', 'None', 'To discuss medication options and therapy', 'Worried about the frequency and intensity of my symptoms', 'Panicked and on edge']
df_mental.loc[45] = ['Feeling down, anxious, and stressed', 'Mood swings, irritability, sleep problems', '1 month', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the impact on my daily life', 'Frustrated and overwhelmed']
df_mental.loc[46] = ['Difficulty coping with daily life', 'Anxiety, lack of motivation, social withdrawal', '3 months', 'Mental health issues', 'Severe', 'Life stressors', 'None', 'None', 'To discuss medication options and therapy options', 'Worried about the long-term effects', 'Hopeless and helpless']
df_mental.loc[47] = ['Feeling overwhelmed and disconnected', 'Depression, loss of interest in activities', '6 months', 'Mental health issues', 'Mild', 'Unknown', 'None', 'None', 'To receive support and guidance', 'Concerned about the stigma surrounding mental health', 'Isolated and alone']
df_mental.loc[48] = ['Struggling with managing stress', 'Stress, irritability, difficulty concentrating', '2 weeks', 'Mental health issues', 'Moderate', 'Work and personal stressors', 'None', 'None', 'To develop strategies for managing stress', 'Afraid of the consequences of not addressing my mental health', 'Exhausted and drained']
df_mental.loc[49] = ['Feeling down and disconnected from others', 'Depression, lack of motivation, social withdrawal', '1 year', 'Mental health issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a comprehensive evaluation and treatment plan', 'Concerned about the impact on my relationships', 'Lonely and sad']
df_mental.loc[50] = ["Feeling overwhelmed and stressed", "Stress, anxiety, mood swings", "2 months", "Mental health issues", "Severe", "Unknown", "None", "None", "To receive a diagnosis and start treatment", "Worried about the impact on my relationships and work", "Stressed and anxious"]
df_mental.loc[51] = ["Needing help with depression", "Depression, social withdrawal, lack of motivation", "1 year", "Mental health issues", "Moderate", "Unknown", "None", "None", "To discuss medication options and receive support", "Concerned about the long-term effects of my symptoms", "Depressed and hopeless"]
df_mental.loc[52] = ["Experiencing sleep problems and mood swings", "Sleep problems, mood swings, irritability", "3 weeks", "Mental health issues", "Mild", "Unknown", "None", "None", "To receive a diagnosis and treatment plan", "Worried about the cause of my symptoms", "Exhausted and emotional"]
df_mental.loc[53] = ['Feeling overwhelmed and anxious', 'Depression, irritability, sleep problems', '2 months', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To discuss treatment options with my healthcare provider', 'Concerned about the impact of my symptoms on my daily life', 'Feeling hopeless and helpless']
df_mental.loc[54] = ['Needing support for my mental health', 'Anxiety, stress, mood swings', '6 months', 'Mental health issues', 'Severe', 'Life events', 'None', 'None', 'To receive support and guidance from my healthcare provider', 'Worried about the long-term effects of my symptoms', 'Feeling lost and alone']
df_mental.loc[55] = ['Seeking help for my mental health struggles', 'Depression, lack of motivation, social withdrawal', '1 year', 'Mental health issues', 'Mild', 'Unknown', 'None', 'None', 'To learn coping strategies and improve my mental wellbeing', 'Concerned about the stigma surrounding mental health', 'Feeling misunderstood and unsupported']
df_mental.loc[56] = ['Feeling overwhelmed by my mental health issues', 'Anxiety, stress, difficulty concentrating', '3 months', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To discuss medication options with my healthcare provider', 'Worried about the effect of my symptoms on my relationships', 'Feeling frustrated and exhausted']
df_mental.loc[57] = ['Feeling anxious and depressed', 'Mood swings, irritability, social withdrawal', '6 months', 'Mental health issues', 'Moderate', 'Life stressors', 'Insomnia', 'None', 'To receive support and guidance on managing my symptoms', 'Concerned about the long-term effects on my mental health', 'Frustrated and overwhelmed']
df_mental.loc[58] = ['Need support for anxiety and stress', 'Difficulty concentrating, lack of motivation', '3 weeks', 'Anxiety and stress', 'Mild', 'Work and relationship stress', 'None', 'None', 'To discuss treatment options and coping strategies', 'Worried about my ability to perform well at work', 'Exhausted and drained']
df_mental.loc[59] = ['Feeling down and hopeless', 'Loss of interest in activities, sleep problems', '1 month', 'Depression', 'Severe', 'Unknown', 'None', 'History of depression', 'To get a referral for therapy and medication', 'Fearful of the potential consequences of my symptoms', 'Hopeless and helpless']
df_mental.loc[60] = ['Need help managing stress and anxiety', 'Sleep problems, irritability', '2 months', 'Stress and anxiety', 'Moderate', 'Work and personal life stressors', 'None', 'None', 'To learn effective coping strategies and stress management techniques', 'Afraid of burning out and losing control', 'Overwhelmed and stressed']
df_mental.loc[61] = ['Feeling anxious and depressed', 'Excessive worrying, difficulty sleeping, low mood', '6 months', 'Mental health issues', 'Moderate', 'Unknown', 'None', 'None', 'To receive support and treatment', 'Concerned about the impact on my daily life', 'Feeling overwhelmed and helpless']
df_mental.loc[62] = ['Struggling with stress and mood swings', 'Difficulty concentrating, irritability, low energy', '3 months', 'Mental health issues', 'Mild', 'Work and personal stress', 'None', 'None', 'To improve my mood and manage stress', 'Worried about my overall wellbeing', 'Feeling frustrated and drained']
df_mental.loc[63] = ['Feeling down and isolated', 'Lack of motivation, loss of interest in activities, social withdrawal', '2 weeks', 'Mental health issues', 'Severe', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
df_mental.loc[64] = ['Experiencing sleep problems', 'Difficulty falling and staying asleep, waking up feeling tired', '1 month', 'Mental health issues', 'Mild', 'Unknown', 'None', 'None', 'To improve my sleep quality', 'Worried about the long-term effects on my health', 'Frustrated and exhausted']
df_mental.loc[65] = ['Loss of interest in activities, mood swings, sleep problems', 'Fatigue, irritability, difficulty concentrating', '6 months', 'Mental health', 'Moderate', 'Work stress and relationship problems', 'Headaches, muscle tension', 'None', 'Medication and therapy', 'Feeling like I\'m not myself and losing control', 'Frustrated and hopeless']
df_mental.loc[66] = ['Depression, anxiety, stress', 'Panic attacks, obsessive thoughts, phobias', '1 year', 'Mental health', 'Severe', 'Trauma and genetic predisposition', 'Weight changes, physical symptoms of anxiety', 'None', 'Medication, therapy, and self-care strategies', 'Worried about the long-term effects on my health and relationships', 'Overwhelmed and scared']
df_mental.loc[67] = ['Mood swings, irritability, social withdrawal', 'Insomnia, difficulty concentrating, lack of motivation', '2 months', 'Mental health', 'Mild', 'Unknown', 'None', 'None', 'To discuss my symptoms and potential treatment options', 'Concerned about the impact on my work and personal life', 'Curious and anxious']
df_mental.loc[68] = ['Stress, anxiety, sleep problems', 'Panic attacks, obsessive thoughts, phobias', '1 year', 'Mental health', 'Moderate', 'Work stress and relationship problems', 'Headaches, muscle tension', 'None', 'Medication and therapy', 'Feeling like I\'m not myself and losing control', 'Frustrated and hopeless']
df_mental.loc[69] = ['Depression, anxiety, mood swings', 'Sleep problems, irritability, difficulty concentrating', '6 months', 'Mental health', 'Moderate', 'Unknown', 'None', 'None', 'To discuss my symptoms and receive a treatment plan', 'Worried that my symptoms are getting worse', 'Frustrated and overwhelmed']
df_mental.loc[70] = ['Stress, loss of motivation', 'Lack of interest in activities, social withdrawal', '1 year', 'Mental health', 'Severe', 'Unknown', 'None', 'None', 'To receive support and guidance for managing my symptoms', 'Concerned about the impact of my symptoms on my daily life', 'Hopeless and helpless']
df_mental.loc[71] = ['Feeling down, overwhelmed', 'Irritability, sleep problems', '3 months', 'Mental health', 'Mild', 'Unknown', 'None', 'None', 'To talk to a professional about my symptoms and learn coping strategies', 'Nervous about seeking help for my mental health', 'Anxious and uncertain']
df_mental.loc[72] = ['Anxiety, stress', 'Mood swings, difficulty concentrating', '2 weeks', 'Mental health', 'Moderate', 'Unknown', 'None', 'None', 'To receive a diagnosis and treatment plan', 'Concerned about the cause of my symptoms', 'Scared and anxious']
"""
